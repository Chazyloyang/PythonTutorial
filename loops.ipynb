# %% [markdown]
# ## Loops in Python

# %% [markdown]
# A loop is code used to perform an operation repeatedly until a condition is being fulfilled.
#
# # Types of loops
# There are three types of loops in python. We have the for loop, the while loop and the do while loop.

# %% [markdown]
# # For loop
# The for loop is used to perform an operation repatedly

# %%
# Example of a for loop with Python
#Print "Hello World!" the number of  times as the user's input
print("We will say Hello to you baesed on the number you give me")
name=input("What is your name?")
m = int(input("How many times should we greet you?"))
for(i<m){

}
